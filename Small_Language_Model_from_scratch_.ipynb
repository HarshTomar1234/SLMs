# %% [markdown]
# # Introduction
#
# Let us build a Small Language Model (SLM) from scratch. We will try to keep the parameter size to 50-60 million.
#
# Our goal is to generate creative and coherent text based on the input data.

# %% [markdown]
# # Small Language Models (SLMs):
#
# ## 1. Definition and Overview
#
# ### What are Small Language Models?
# Small Language Models (SLMs) are compact artificial intelligence systems designed to process, understand, and generate human language with significantly fewer parameters than their larger counterparts. They're called "small" because they have a relatively small number of parameters compared to large language models (LLMs) like GPT-3.
#
# ### Parameter Range
# SLMs are models that fit the 500 million to 20 billion parameter range, while LLMs hit the 20 billion parameter mark and beyond. This categorization follows the definitions provided by Gartner and Deloitte.
#
# ### Core Characteristics
# - **Compact Architecture**: Fewer parameters and smaller model size
# - **Efficiency-Focused**: Optimized for speed and resource conservation
# - **Task-Specific**: Often specialized for particular domains or applications
# - **Deployment Flexibility**: Can run on edge devices and consumer hardware
#
# ## 2. Key Advantages of SLMs
#
# ### Performance Benefits
# - **Faster Inference**: Reduced latency due to smaller model size
# - **Lower Computational Requirements**: Can run on standard hardware without specialized GPUs
# - **Quick Training and Fine-tuning**: Faster iteration cycles for customization
# - **Real-time Processing**: Enable responsive applications and interactive experiences
#
# ### Economic Advantages
# - **Cost-Effective**: Lower infrastructure and operational costs
# - **Reduced Energy Consumption**: More environmentally sustainable
# - **Accessible to SMBs**: They're faster, easier to deploy, and often more secure—a dream combination for any SMB.
#
# ### Security and Privacy
# - **On-Device Deployment**: Data remains local, enhancing privacy
# - **Easier Auditing**: SLMs, being smaller and more focused, might be easier to audit and secure, providing greater control over data privacy and data security.
# - **Better Control**: Organizations maintain full ownership of their AI infrastructure
#
# ## 3. Leading SLM Models in 2025
#
# ### Top Models by Performance
#
# #### Meta's Llama Family
# - **Llama 3.1 8B**: Industry-leading performance in the 8B parameter class
# - **Llama 3.2 1B and 3B**: Ultra-compact models for mobile deployment
#
# #### Microsoft's Phi Series
# - **Phi-3.5**: Advanced reasoning capabilities in a small package
# - **Phi-3 Mini (3.8B)**: Optimized for mobile and edge devices
#
# #### Google's Gemma Models
# - **Gemma 2 (2B, 9B)**: Strong multilingual capabilities
# - **Gemma Nano**: Designed for on-device applications
#
# #### Mistral Models
# - **Mistral 7B**: Excellent balance of size and capability
# - **Mistral Nemo**: Collaboration with NVIDIA for optimized performance
#
# #### Other Notable Models
# - **Qwen 2 Series**: Strong performance on Asian languages
# - **StableLM**: Open-source models from Stability AI
# - **Falcon 7B**: Excellent for Arabic and English tasks
#
# ## 4. NVIDIA's Contributions to SLMs
#
# ### Nemotron Family
# The NVIDIA Llama Nemotron models use NVIDIA NeMo for distilling, pruning and alignment.
#
# #### Nemotron-Mini-4B
# - Uses a model embedding size of 3072, 32 attention heads, and an MLP intermediate dimension of 9216.
# - Optimized through distillation, pruning and quantization for speed and on-device deployment.
# - Specialized for roleplay, RAG QA, and function calling
#
# ### Key Technologies
#
# #### Model Optimization Techniques
# 1. **Distillation**: The process of training a smaller model (called a student) to mimic the outputs of a larger model (a teacher).
# 2. **Pruning**: The process of removing non-critical outputs of the student model.
# 3. **Quantization**: The process of reducing the precision of a model's weights.
#
# #### Minitron Models
# "We combined two different AI optimization methods — pruning to shrink Mistral NeMo's 12 billion parameters into 8 billion, and distillation to improve accuracy."
#
# Benefits of NVIDIA's approach:
# - Improvement in MMLU scores by 16% compared to training from scratch.
# - Reduced latency for real-time applications
# - Enhanced efficiency for edge deployment
#
# ### NVIDIA NeMo Platform
# - End-to-end platform for developing custom generative AI
# - Tools for model customization, optimization, and deployment
# - Support for various optimization techniques
#
# ## 5. Technical Architecture and Design
#
# ### Common Architectural Features
# - **Transformer-based**: Most SLMs use transformer decoder architecture
# - **Attention Mechanisms**: Grouped-Query Attention (GQA) for efficiency
# - **Position Encoding**: Rotary Position Embeddings (RoPE) for better context understanding
# - **Context Windows**: Typically 2K-8K tokens (some extending to 32K+)
#
# ### Optimization Strategies
# 1. **Knowledge Distillation**: Transfer knowledge from larger models
# 2. **Structured Pruning**: Remove redundant parameters systematically
# 3. **Mixed Precision Training**: Use lower precision for faster computation
# 4. **Efficient Attention**: Flash Attention and other optimized implementations
#
# ## 6. Use Cases and Applications
#
# ### Enterprise Applications
# - **Customer Service**: Chatbots and virtual assistants
# - **Code Review**: Fine-tuning small language models to optimize code review accuracy
# - **Document Processing**: Summarization and information extraction
# - **Content Generation**: Marketing copy and technical documentation
#
# ### Edge and Mobile Deployment
# - **Gaming**: 'Mecha BREAK' is the first game to showcase ACE technology, including NVIDIA Nemotron-4 4B, for quicker, more relevant responses.
# - **IoT Devices**: Smart home assistants and industrial sensors
# - **Mobile Apps**: On-device translation and text processing
# - **Automotive**: In-vehicle assistants and navigation systems
#
# ### Specialized Domains
# - **Healthcare**: Medical documentation and patient interaction
# - **Education**: Personalized tutoring and assessment
# - **Finance**: Risk analysis and compliance checking
# - **Legal**: Contract analysis and legal research
#
# ## 7. Market Trends and Future Outlook (2025)
#
# ### Industry Growth
# As the initial hype surrounding GenAI continues to mellow, the market impact of small language models (SLMs) is set to soar.
#
# ### Key Market Players
# The 2025 SLM landscape will be characterized by a dynamic ecosystem including technology giants (Microsoft, Meta, Google, Apple), specialized AI startups, and a growing open-source community.
#
# ### Emerging Trends
# 1. **Agentic AI**: The rapid rise of agentic AI has reshaped how enterprises, developers, and entire industries think about automation and digital productivity.
# 2. **Hybrid Architectures**: Combining SLMs with larger models for optimal performance
# 3. **Domain Specialization**: Industry-specific models with targeted capabilities
# 4. **Federated Learning**: Training models across distributed devices
#
# ## 8. Development Best Practices
#
# ### Model Selection Criteria
# - **Task Requirements**: Match model capabilities to specific needs
# - **Resource Constraints**: Consider available hardware and budget
# - **Latency Requirements**: Real-time vs. batch processing needs
# - **Data Privacy**: On-premise vs. cloud deployment considerations
#
# ### Fine-tuning Strategies
# - **Domain-Specific Data**: Use high-quality, relevant datasets
# - **Transfer Learning**: Leverage pre-trained models as starting points
# - **Continuous Learning**: Implement feedback loops for improvement
# - **A/B Testing**: Compare different model versions in production
#
# ### Deployment Considerations
# - **Hardware Optimization**: Use appropriate accelerators (NPUs, TPUs)
# - **Model Serving**: Implement efficient inference pipelines
# - **Monitoring**: Track performance metrics and model drift
# - **Scaling**: Plan for horizontal and vertical scaling needs
#
# ## 9. Challenges and Limitations
#
# ### Technical Challenges
# - **Limited Context Windows**: Smaller models often have shorter context lengths
# - **Reduced Capabilities**: May struggle with complex reasoning tasks
# - **Specialization Trade-offs**: Optimizing for specific tasks may reduce generalization
#
# ### Practical Considerations
# - **Training Data Quality**: Requires high-quality, curated datasets
# - **Maintenance Overhead**: LLMs might require more effort and resources to retrain and update due to their size and complexity.
# - **Integration Complexity**: May need multiple specialized models
#
# ## 10. Comparison: SLMs vs. LLMs
#
# ### When to Choose SLMs
# - Resource-constrained environments
# - Real-time processing requirements
# - Privacy-sensitive applications
# - Specific, well-defined tasks
# - Edge deployment scenarios
#
# ### When to Choose LLMs
# - Complex reasoning tasks
# - General-purpose applications
# - Research and development
# - Tasks requiring extensive world knowledge
# - Creative and open-ended generation
#
# ## 11. Open Source Ecosystem
#
# ### Key Frameworks
# - **Hugging Face Transformers**: Extensive model library and tools
# - **ONNX Runtime**: Cross-platform inference optimization
# - **TensorFlow Lite**: Mobile and embedded deployment
# - **PyTorch Mobile**: On-device machine learning
#
# ### Community Initiatives
# - Model sharing platforms
# - Benchmark suites for evaluation
# - Collaborative research projects
# - Educational resources and tutorials
#
# ## 12. Future Directions
#
# ### Technical Innovations
# - **Neural Architecture Search**: Automated model design
# - **Sparse Models**: More efficient parameter utilization
# - **Multi-modal SLMs**: Text, vision, and audio in compact models
# - **Neuromorphic Computing**: Brain-inspired architectures
#
# ### Industry Evolution
# - Standardization of model formats
# - Regulatory frameworks for AI deployment
# - Increased focus on sustainability
# - Democratization of AI technology
#
# ## Conclusion
#
# Small Language Models represent a crucial evolution in AI technology, making advanced natural language processing accessible, affordable, and practical for a wide range of applications. As we move through 2025, SLMs are proving that bigger isn't always better, and that carefully optimized, task-specific models can deliver exceptional value while addressing critical concerns around cost, privacy, and sustainability. The contributions from companies like NVIDIA, along with the vibrant open-source community, are accelerating innovation and adoption across industries, making SLMs a cornerstone of the modern AI landscape.

# %% [markdown]
# ## Step 1: Import the Dataset
#
# TinyStories is a synthetic dataset of short stories that only contain words that a typical 3 to 4-year-olds usually understand, generated by GPT-3.5 and GPT-4. We can get it from HuggingFace.

# %%
# !pip install datasets

# %%
pip install -U datasets

# %%
from datasets import load_dataset

ds = load_dataset("roneneldan/TinyStories")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md: 0.00B [00:00, ?B/s]
# (…)-00000-of-00004-2d5a1467fff1081b.parquet:   0%|          | 0.00/249M [00:00<?, ?B/s]
# (…)-00001-of-00004-5852b56a2bd28fd9.parquet:   0%|          | 0.00/248M [00:00<?, ?B/s]
# (…)-00002-of-00004-a26307300439e943.parquet:   0%|          | 0.00/246M [00:00<?, ?B/s]
# (…)-00003-of-00004-d243063613e5a057.parquet:   0%|          | 0.00/248M [00:00<?, ?B/s]
# ...

# %% [markdown]
# ## Step 2: Tokenize the Dataset
#
# ### There are 2 million rows in Training Data
#
# ### 20000 rows in validation Data

# %% [markdown]
# # Note
#
# Here we're using GPT-2 sub-word tokenizer (Byte Pair Encoding)
#
# for example lets take a story -->
#
# One day, a little girl named Lily found a needle in her room. She knew it was difficult to play with it because it was sharp. Lily wanted to share the needle with her mom, so she could sew a button on her shirt.
#
#
# This complete above text will be converted into tokens -
#
# [442, 518, 11, 257, 6142, 1038, 1433, 1595, 257, 2729, 287, 530, 554]
#
# {'ids': [442, 518, 11, 257, 6142, 1038, 1433, 1595, 257, 2729, 287, 530, 554],
#
# 'len': 13}
#
# These no. are typically numerical represenation of above text and in this way we'll represent stories
#
# `We'll store all tokenIDs in a single bin file`
#
# `We'll store this on disk storage`
#
# Reason:
#
# 1. Efficiency --> Fast data loading during training
#
# 2. Memory --> Avoids RAM overload on big datasets
#
# 3. Persistence --> No need to re-tokenize
#
# 4. Simplicity --> Flat format is easy to use
#
# 5. Reuse --> You can re-use the .bin for multiple trainings

# %% [markdown]
# In this step, we will do the following:
#
# (1) Tokenize the dataset into tokenIDs.
#
# (2) Create a file called "train.bin" and "validation.bin" where we will store the tokenIDs from the entire dataset.
#
# (3) We make sure the tokenIDs are stored on a disk, rather than on the RAM for efficient computations.
#
# ### Remember we're also splitting  dataset  into batches and then adding everything to bin file for faster computations and parallel processing...

# %%
# !pip install tiktoken
import tiktoken
import os
import numpy as np
from tqdm.auto import tqdm

enc = tiktoken.get_encoding("gpt2")

# Some functions from https://github.com/karpathy/nanoGPT/blob/master/data/openwebtext/prepare.py

def process(example):
    ids = enc.encode_ordinary(example['text']) # encode_ordinary ignores any special tokens
    out = {'ids': ids, 'len': len(ids)}
    return out

if not os.path.exists("train.bin"):
    tokenized = ds.map(
        process,
        remove_columns=['text'],
        desc="tokenizing the splits",
        num_proc=8,
        )
    # concatenate all the ids in each dataset into one large file we can use for training
    for split, dset in tokenized.items():
        arr_len = np.sum(dset['len'], dtype=np.uint64)
        filename = f'{split}.bin'
        dtype = np.uint16 # (can do since enc.max_token_value == 50256 is < 2**16)
        arr = np.memmap(filename, dtype=dtype, mode='w+', shape=(arr_len,))
        total_batches = 1024

        idx = 0
        for batch_idx in tqdm(range(total_batches), desc=f'writing {filename}'):
            # Batch together samples for faster write
            batch = dset.shard(num_shards=total_batches, index=batch_idx, contiguous=True).with_format('numpy')
            arr_batch = np.concatenate(batch['ids'])
            # Write into mmap
            arr[idx : idx + len(arr_batch)] = arr_batch
            idx += len(arr_batch)
        arr.flush()
# Out:
# ...
# writing validation.bin:   0%|          | 0/1024 [00:00<?, ?it/s]

# %% [markdown]
# ## Step 3: Create Input-Output batches for the dataset

# %% [markdown]
# ##### context_size = maximum no. of tokens language model can look at before predicting the next token and here it is set to 4 ....basically a chunk of 4 words (4 tokenids)
#
#
# ##### batch_size = during training all input-output pairs are not processed at the same time we processed  it using batches ..here batch size is taken as 4
#
# ![image.png](data:image/png;base64,...)

# %%
# Some functions from https://github.com/karpathy/nanoGPT/blob/master/train.py with slight modifications
#block size = context window
def get_batch(split):
    # We recreate np.memmap every batch to avoid a memory leak, as per
    # https://stackoverflow.com/questions/45132940/numpy-memmap-memory-usage-want-to-iterate-once/61472122#61472122
    if split == 'train':
        data = np.memmap('train.bin', dtype=np.uint16, mode='r')
    else:
        data = np.memmap('validation.bin', dtype=np.uint16, mode='r')
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([torch.from_numpy((data[i:i+block_size]).astype(np.int64)) for i in ix])
    y = torch.stack([torch.from_numpy((data[i+1:i+1+block_size]).astype(np.int64)) for i in ix])
    if device_type == 'cuda':
        # pin arrays x,y, which allows us to move them to GPU asynchronously (non_blocking=True)
        x, y = x.pin_memory().to(device, non_blocking=True), y.pin_memory().to(device, non_blocking=True)
    else:
        x, y = x.to(device), y.to(device)
    return x, y


    # Normally to(device) blocks CPU until copy to GPU finishes
    # non_blocking = True allows CPU to continue doing other tasks (like next batch preparation)

# %% [markdown]
# ## Step 4: Define the SLM Model Architecture

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import math
from dataclasses import dataclass
import numpy as np
from tqdm.auto import tqdm
from contextlib import nullcontext
import os

class LayerNorm(nn.Module):
    def __init__(self, ndim, bias):
        super().__init__()
        self.weight = nn.Parameter(torch.ones(ndim))
        self.bias = nn.Parameter(torch.zeros(ndim)) if bias else None
    def forward(self, x):
        return F.layer_norm(x, self.weight.shape, self.weight, self.bias, 1e-5)

class CausalSelfAttention(nn.Module):
    def __init__(self, config):
        super().__init__()
        assert config.n_embd % config.n_head == 0
        self.c_attn = nn.Linear(config.n_embd, 3 * config.n_embd, bias=config.bias)
        self.c_proj = nn.Linear(config.n_embd, config.n_embd, bias=config.bias)
        self.attn_dropout = nn.Dropout(config.dropout)
        self.resid_dropout = nn.Dropout(config.dropout)
        self.n_head = config.n_head
        self.n_embd = config.n_embd
        self.flash = hasattr(F, 'scaled_dot_product_attention')
        if not self.flash:
            self.register_buffer("bias", torch.tril(torch.ones(config.block_size, config.block_size))
                                       .view(1, 1, config.block_size, config.block_size))

    def forward(self, x):
        B, T, C = x.size()
        q, k, v = self.c_attn(x).split(self.n_embd, dim=2)
        k = k.view(B, T, self.n_head, C // self.n_head).transpose(1, 2)
        q = q.view(B, T, self.n_head, C // self.n_head).transpose(1, 2)
        v = v.view(B, T, self.n_head, C // self.n_head).transpose(1, 2)

        if self.flash:
            y = F.scaled_dot_product_attention(q, k, v, attn_mask=None, dropout_p=self.attn_dropout.p if self.training else 0.0, is_causal=True)
        else:
            att = (q @ k.transpose(-2, -1)) * (1.0 / math.sqrt(k.size(-1)))
            att = att.masked_fill(self.bias[:, :, :T, :T] == 0, float('-inf'))
            att = F.softmax(att, dim=-1)
            att = self.attn_dropout(att)
            y = att @ v

        y = y.transpose(1, 2).contiguous().view(B, T, C)
        y = self.resid_dropout(self.c_proj(y))
        return y

class MLP(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.c_fc = nn.Linear(config.n_embd, 4 * config.n_embd, bias=config.bias)
        self.gelu = nn.GELU()
        self.c_proj = nn.Linear(4 * config.n_embd, config.n_embd, bias=config.bias)
        self.dropout = nn.Dropout(config.dropout)
    def forward(self, x):
        return self.dropout(self.c_proj(self.gelu(self.c_fc(x))))

# Transformer block
class Block(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.ln1 = LayerNorm(config.n_embd, config.bias)
        self.attn = CausalSelfAttention(config)
        self.ln2 = LayerNorm(config.n_embd, config.bias)
        self.mlp = MLP(config)
    def forward(self, x):
        x = x + self.attn(self.ln1(x))
        x = x + self.mlp(self.ln2(x))
        return x

@dataclass
class GPTConfig:
    block_size: int
    vocab_size: int
    n_layer: int
    n_head: int
    n_embd: int
    dropout: float = 0.0
    bias: bool = True

class GPT(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config
        self.transformer = nn.ModuleDict(dict(
            wte=nn.Embedding(config.vocab_size, config.n_embd),
            wpe=nn.Embedding(config.block_size, config.n_embd),
            drop=nn.Dropout(config.dropout),
            h=nn.ModuleList([Block(config) for _ in range(config.n_layer)]),
            ln_f=LayerNorm(config.n_embd, config.bias),
        ))
        self.lm_head = nn.Linear(config.n_embd, config.vocab_size, bias=False)
        self.transformer.wte.weight = self.lm_head.weight  # weight tying

        self.apply(self._init_weights)
        for pn, p in self.named_parameters():
            if pn.endswith('c_proj.weight'):
                nn.init.normal_(p, mean=0.0, std=0.02 / math.sqrt(2 * config.n_layer))

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            nn.init.normal_(module.weight, mean=0.0, std=0.02)

    def forward(self, idx, targets=None):
        device = idx.device
        b, t = idx.size()
        assert t <= self.config.block_size
        pos = torch.arange(0, t, dtype=torch.long, device=device)

        tok_emb = self.transformer.wte(idx)
        pos_emb = self.transformer.wpe(pos)
        x = self.transformer.drop(tok_emb + pos_emb)
        for block in self.transformer.h:
            x = block(x)
        x = self.transformer.ln_f(x)

        if targets is not None:
            logits = self.lm_head(x)
            loss = F.cross_entropy(logits.view(-1, logits.size(-1)), targets.view(-1), ignore_index=-1)
            return logits, loss
        else:
            logits = self.lm_head(x[:, [-1], :])
            return logits, None

    @torch.no_grad()
    def generate(self, idx, max_new_tokens, temperature=1.0, top_k=None):
        """
        Generate tokens given a conditioning sequence.
        idx: Tensor of shape (B, T)
        """
        for _ in range(max_new_tokens):
            idx_cond = idx if idx.size(1) <= self.config.block_size else idx[:, -self.config.block_size:]
            logits, _ = self(idx_cond)
            logits = logits[:, -1, :] / temperature
            if top_k is not None:
                v, _ = torch.topk(logits, min(top_k, logits.size(-1)))
                logits[logits < v[:, [-1]]] = -float('Inf')
            probs = F.softmax(logits, dim=-1)
            idx_next = torch.multinomial(probs, num_samples=1)
            idx = torch.cat((idx, idx_next), dim=1)
        return idx

# %%
config = GPTConfig(
    vocab_size=50257,     # use the tokenizer's vocab size
    block_size=128,       # or whatever context size you're training with
    n_layer=6,            # n_layers = number of transformer blocks
    n_head=6,             # number of attention heads
    n_embd=384,           # embedding dimension
    dropout=0.1,
    bias=True
)

model = GPT(config)

# %% [markdown]
# ## Step 5: Define the loss function

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
def estimate_loss(model):
    out = {}
    model.eval()
    with torch.inference_mode():
        for split in ['train', 'val']:
            losses = torch.zeros(eval_iters)
            for k in range(eval_iters):
                X, Y = get_batch(split)
                with ctx:
                    logits, loss = model(X, Y)
                losses[k] = loss.item()
            out[split] = losses.mean()
    model.train()
    return out

# %% [markdown]
# ## Step 6: Define SLM Training Configuration Part 1

# %% [markdown]
# ---
#
# ### 🔹 What is `autocast` in PyTorch?
#
# `torch.amp.autocast` is part of **Automatic Mixed Precision (AMP)** in PyTorch.
#
# * **Mixed Precision Training** = Using **both 16-bit (float16/bfloat16)** and **32-bit (float32)** floating-point numbers in training.
# * `autocast` automatically decides *which operations should run in lower precision* (to save memory & speed up) and *which must stay in full precision* (to avoid numerical instability).
#
# So inside an `autocast` context:
#
# ```python
# with torch.amp.autocast(device_type="cuda", dtype=torch.float16):
#     output = model(input)
#     loss = criterion(output, target)
# ```
#
# * **Matrix multiplications, convolutions** → run in float16/bfloat16 (fast, memory-efficient).
# * **Loss calculation, softmax, reductions** → run in float32 (to keep stability).
#
# ---
#
# ### 🔹 Why do we need it in production-ready training?
#
# 1. **Speed-up Training**
#
#    * On GPUs with Tensor Cores (like NVIDIA RTX/A100), FP16/bfloat16 ops are much faster.
#    * Autocast ensures you benefit from this automatically.
#
# 2. **Lower Memory Usage**
#
#    * FP16/bfloat16 use half the memory of FP32.
#    * Larger batch sizes & deeper models can fit into VRAM.
#
# 3. **Numerical Safety**
#
#    * Some ops (e.g., softmax, exponentials, reductions) are unstable in FP16 → `autocast` automatically keeps them in FP32.
#
# 4. **Ease of Integration**
#
#    * You don’t manually cast every tensor. Just wrap your forward pass with `autocast`, and PyTorch decides precision per operation.
#
# ---
#
# ### 🔹In our code
#
# ```python
# ctx = nullcontext() if device_type == 'cpu' else torch.amp.autocast(
#     device_type=device_type,
#     dtype=ptdtype
# )
# ```
#
# * On **CPU** → precision gains aren’t helpful, so it uses `nullcontext()` (i.e., no effect).
# * On **GPU** → wraps training in an autocast context with chosen dtype (`float16` or `bfloat16`).
#
# Later in training loop, you’ll likely see something like:
#
# ```python
# with ctx:
#     logits = model(x)
#     loss = loss_fn(logits, y)
# ```
#
# That means:
#
# * If CUDA → mixed precision will automatically be applied.
# * If CPU → runs normally without precision changes.
#
# ---
#
# ### 🔹 Difference between `float16` and `bfloat16`
#
# * **float16** → faster, but has smaller dynamic range (risk of underflow/overflow).
# * **bfloat16** → almost same range as float32, but fewer precision bits. More stable in training, supported on modern GPUs/TPUs.
#
# our code:
#
# ```python
# dtype = 'bfloat16' if torch.cuda.is_available() and torch.cuda.is_bf16_supported() else 'float16'
# ```
#
# This ensures **best available precision** is used on GPU.
#
# ---
# ✅**In summary**:
# `autocast` makes your training loop *production-ready* by giving you **the speed/memory benefits of mixed precision** while avoiding precision errors that could crash training. Without it, you’d either waste resources training in full float32 or risk instability casting everything to float16 manually.
#
# ---

# %% [markdown]
# ### Gradient Accumulation
#
#  1. You want to train with batch_size of 1024
#
#  2. But your GPU only fits batch_size 32
#
#  3. you have to set:
#
# ` gradient_accumulation_steps = 32`
#
# Run 32 iterations with batch_size = 32
#
# Accumulate gradients during `loss.backward()`
#
# Then do `optimizer.step()` after 32 steps means update parameters after every 32 steps

# %%
# Training Config
import torch
from contextlib import nullcontext

learning_rate = 1e-4 #more stable training, earlier 1e-4
max_iters = 20000 #increase from 25000
warmup_steps = 1000 #smoother initial train, earlier 100
min_lr = 5e-4 #lower rate, earlier 5e-4
eval_iters = 500 # increased from 100
batch_size = 32 # changed from 16, better gradient estimate
block_size = 128 #changed from 64, capture longer range dependencies

gradient_accumulation_steps = 32 # reduced from 50

device =  "cuda" if torch.cuda.is_available() else "cpu"
device_type = 'cuda' if 'cuda' in device else 'cpu' # for later use in torch.autocast
# note: float16 data type will automatically use a GradScaler

# How to use autocast https://wandb.ai/wandb_fc/tips/reports/How-To-Use-Autocast-in-PyTorch--VmlldzoyMTk4NTky
#dtype = 'bfloat16' if torch.cuda.is_available() and torch.cuda.is_bf16_supported() else 'float16' # 'float32', 'bfloat16', or 'float16', the latter will auto implement a GradScaler
dtype = 'bfloat16' if torch.cuda.is_available() and torch.cuda.is_bf16_supported() else 'float16' # 'float32', 'bfloat16', or 'float16', the latter will auto implement a GradScaler
ptdtype = {'float32': torch.float32, 'bfloat16': torch.bfloat16, 'float16': torch.float16}[dtype]

ctx = nullcontext() if device_type == 'cpu' else torch.amp.autocast(device_type=device_type, dtype=ptdtype)

torch.set_default_device(device)
torch.manual_seed(42)

# %% [markdown]
# ## Step 7: Define SLM Training Configuration Part 2

# %%
from torch.optim.lr_scheduler import LinearLR,SequentialLR, CosineAnnealingLR

##PUT IN WEIGHT DECAY, CHANGED BETA2 to 0.95
optimizer =  torch.optim.AdamW(model.parameters(), lr=learning_rate, betas=(0.9, 0.95), weight_decay=0.1, eps=1e-9) #weight decay for regularization

scheduler_warmup = LinearLR(optimizer, total_iters = warmup_steps) #Implement linear warmup
scheduler_decay = CosineAnnealingLR(optimizer,T_max = max_iters - warmup_steps, eta_min = min_lr) #Implement lr decay
scheduler = SequentialLR(optimizer, schedulers=[scheduler_warmup, scheduler_decay], milestones=[warmup_steps]) #Switching from warmup to decay

# https://stackoverflow.com/questions/72534859/is-gradscaler-necessary-with-mixed-precision-training-with-pytorch
scaler = torch.cuda.amp.GradScaler(enabled=(dtype == 'float16'))
# Out:
# /tmp/ipython-input-2132813893.py:11: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=(dtype == 'float16'))

# %% [markdown]
# ## Step 8: Pre-train the SLM

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
best_val_loss = float('inf')
best_model_params_path = "best_model_params.pt"
train_loss_list, validation_loss_list = [], []

# Ensure model is on the correct device
model = model.to(device)

# In your training loop
for epoch in tqdm(range(max_iters)):
    if epoch % eval_iters == 0 and epoch != 0:
        # Ensure estimate_loss uses the correct device
        losses = estimate_loss(model)
        print(f"Epoch {epoch}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")
        print(f"The current learning rate: {optimizer.param_groups[0]['lr']:.5f}")
        train_loss_list += [losses['train']]
        validation_loss_list += [losses['val']]

        if losses['val'] < best_val_loss:
            best_val_loss = losses['val']
            torch.save(model.state_dict(), best_model_params_path)

    # Ensure X and y are on the correct device
    X, y = get_batch("train")
    X, y = X.to(device), y.to(device)

    with ctx:
        logits, loss = model(X, y)
        loss = loss / gradient_accumulation_steps
        scaler.scale(loss).backward()

    if ((epoch + 1) % gradient_accumulation_steps == 0) or (epoch + 1 == max_iters):
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=0.5)
        scaler.step(optimizer)
        scaler.update()
        optimizer.zero_grad(set_to_none=True)
    scheduler.step()
# Out:
#   0%|          | 0/20000 [00:00<?, ?it/s]
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:227: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn(
# Epoch 500: train loss 9.4434, val loss 9.4478
# The current learning rate: 0.00007
# ...

# %% [markdown]
# ## Step 9: Plot the SLM Loss Function

# %%
import matplotlib.pyplot as plt
train_loss_list_converted = [i.cpu().detach() for i in train_loss_list]
validation_loss_list_converted = [i.cpu().detach() for i in validation_loss_list]

plt.plot(train_loss_list_converted, 'g', label='train_loss')
plt.plot(validation_loss_list_converted, 'r', label='validation_loss')
plt.xlabel("Steps - Every 100 epochs")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %% [markdown]
# ## Step 10: Run SLM Inference on our trained model

# %%
#Load the model
model = GPT(config)  # re-create the model with same config
device =  "cuda" if torch.cuda.is_available() else "cpu"
best_model_params_path = "best_model_params.pt"
model.load_state_dict(torch.load(best_model_params_path, map_location=torch.device(device))) # load best model states
# Out:
# <All keys matched successfully>

# %%
sentence = "Once upon a time there was a pumpkin."
context = (torch.tensor(enc.encode_ordinary(sentence)).unsqueeze(dim = 0))
y = model.generate(context, 200)
print(enc.decode(y.squeeze().tolist()))
# Out:
# Once upon a time there was a pumpkin. It was very special. The pumpkin wanted to paint with its family. So one day, a family decided to make it you all the time. They worked hard to remove something.
#
#  2 laser soldiers traveled and drove it grow into the sky. laughed like the whole."
#
# The pumpkin stopped and smiled and felt happy for the tube. It sounded like it. Give it on big taller than it. They packed it and back up.
#
# When it was done, the pumpkin had closed. It was relaxed and cozy. There were people that flying. Little Thursday workerAlright, the tower could during a bright, normal time. His friend said, "Trn into Lou, what can we do and find our flashlight?"
#
# Her friend thought smellyly and said: "We can try to open it! It can be alright. We can find it".
#
# Joe was amazed. He wanted that if they could delay, they would come back back and mattered the sign

# %%
sentence = "A little girl went to the woods"
context = (torch.tensor(enc.encode_ordinary(sentence)).unsqueeze(dim = 0))
y = model.generate(context, 200)
print(enc.decode(y.squeeze().tolist()))
# Out:
# A little girl went to the woods and he was looking at the animals and he saw a little boy with a big smile on its face. He knew she would never bring medicine before.
#
# One day, the girl called Jeff went for a walk. He saw something pretty in a nearby old structure. It was a kind of creature and he is leaning chillis and hiding. Lilly looked up at the octopus. Littleie felt very worried. She thought it looked colourful and funny. Then found a strange idea. She took the unknown and said, â€œufchieumbling, stone!â€
#
# Ted the factory said, â€œI have a hero!â€; he was sure it will rise.
#
# Mary smiled and was not getting still there before. It was a powerful tw armor! And this made him even more he dream less very safe.It was a awesome day. John saw something sparkly and was a brilliant trick. It was a mighty think of something

# %%
from google.colab import runtime
runtime.unassign()
